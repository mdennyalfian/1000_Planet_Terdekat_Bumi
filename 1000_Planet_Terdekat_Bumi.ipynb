# %%
import csv
import time
import glob
import os
import pandas as pd
import numpy as np

# %%
# Semua dataset yang didownload terbagi menjadi 40 file csv dengan total ukuran 6gb
# file diberi nama 'mdennyalfian@gmail.com_00', 'mdennyalfian@gmail.com_01', 'mdennyalfian@gmail.com_02', dan seterusnya).

# Untuk menemukan 1000 planet terdekat dari bumi dataset dibagi menjadi 13 folder dengan 3-4 file csv/folder

# Langkah Pertama mencari 1000 planet terdekat dari bumi disetiap folder
# Langkah Kedua menggabungkan semua hasil
# Langkah ketiga menemukan 1000 planet terdekat dari bumi dari total 13000 planet

# menggunakan 'time()' untuk merekam proses dari program yang dijalankan

# %%
#________________________________________________PART 1__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan


path =r'C:\Users\DENNY\data\part1'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)


frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted0 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model


timeb1 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 32.714990854263306 seconds ---

# %%
#________________________________________________PART 2__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan


path =r'C:\Users\DENNY\data\part2'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)


frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted1 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model


timeb2 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 35.221091985702515 seconds ---

# %%
#________________________________________________PART 3__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan


path =r'C:\Users\DENNY\data\part3'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)


frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted2 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model


timeb3 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 35.41493487358093 seconds ---

# %%
#________________________________________________PART 4__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part4'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted3 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb4 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 35.23848271369934 seconds ---

# %%
#________________________________________________PART 5__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part5'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted4 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb5 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 34.92062258720398 seconds ---

# %%
#________________________________________________PART 6__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part6'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted5 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb6 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 34.95417499542236 seconds ---

# %%
#________________________________________________PART 7__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part7'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted6 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb7 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 35.0052924156189 seconds ---

# %%
#________________________________________________PART 8__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part8'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted7 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb8 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 35.250579833984375 seconds ---

# %%
#________________________________________________PART 9__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part9'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted8 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb9 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 35.42279648780823 seconds ---

# %%
#________________________________________________PART 10__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part10'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted9 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb10 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 43.5838348865509 seconds ---

# %%
#________________________________________________PART 11__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part11'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted10 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb11 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 34.77881836891174 seconds ---

# %%
#________________________________________________PART 12__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part12'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted11 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb12 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 34.69158983230591 seconds ---

# %%
#________________________________________________PART 13__________________________________________________#

start_time = time.time()  #menghitung waktu proses berjalan

path =r'C:\Users\DENNY\data\part13'   #folder path dari dataset yang dipilih
allFiles = glob.glob(path + "/*.csv") #memanggil semua file csv difolder path
list_ = []
for file_ in allFiles: #menggabungkan semua file csv menjadi satu
    df = pd.read_csv(file_,index_col=None, header=0)
    list_.append(df)
frame = pd.concat(list_, axis = 0, ignore_index = True)
frame.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True) #mengurutkan data
frame_sorted12 = frame.iloc[:1000,:2] #memilih 1000 data disimpan sebagai model

timeb13 = time.time() - start_time 
print('1000 data has been added to dataframe')
print("--- %s seconds ---" % (time.time() - start_time)) #menampilkan total waktu operasi saat proses berjalan
# Out:
# 1000 data has been added to dataframe
# --- 57.10101914405823 seconds ---

# %%
#--------- Menggabungkan semua part menjadi 1 dataframe-------#


# Menjumlah total waktu program berjalan
total_load_time = timeb1+timeb2+timeb3+timeb4+timeb5+timeb6+timeb7+timeb8+timeb9+timeb10+timeb11+timeb12+timeb13


start_time = time.time()

# Menggabungkan dataFrame menjadi 1
frames = [frame_sorted0,
         frame_sorted1,
         frame_sorted2,
         frame_sorted3,
         frame_sorted4,
         frame_sorted5,
         frame_sorted6,
         frame_sorted7,
         frame_sorted8,
         frame_sorted9,
         frame_sorted10,
         frame_sorted11,
         frame_sorted12,]

#Semua part dikombinasikan menjadi satu dataframe(13000 data)
result = pd.concat(frames)

#Menemukan 1000 planet yang mempunyai jarak terdekat dengan bumi
result.sort_values(by='distance_to_earth', ascending=True, na_position='first', inplace=True)
nearest_planet_to_earth = result.iloc[:1000,:2] #memilih 1000 planet terdekat bumi
print(nearest_planet_to_earth) #print dataframe as pandas default
print(nearest_planet_to_earth.to_string()) #print all record


#Mendeskripsikan data dan menemukan MEAN dari data
description = nearest_planet_to_earth.describe()
print(description)

merge_time = time.time() - start_time
print("-------------------------\ntotal merging time = ",merge_time)
# Out:
#            planet_id  distance_to_earth
# 15600657  fae58c52a3              0.000
# 2259599   496e9c1434              0.000
# 17780077  41bb13ca61              0.000
# 9258841   2ccee418d0              0.000
# 17333857  334e722fe2              0.000
# 11757886  7dfe50251e              0.000
# 4384070   8e779d8aa4              0.001
# 7626353   f7d299d24d              0.001
# 6618373   d71488e2dc              0.001
# 17884537  452303fdb4              0.001
# 15575269  fa18f3de4c              0.001
# 23059743  ed49f5062c              0.002
# 6435581   d1122fb906              0.002
# 6283697   cc327b6c01              0.002
# 9955399   4383d54636              0.002
# 3509246   7206fd9366              0.002
# 5549556   b440c583e1              0.003
# 17995370  48c4a82460              0.003
# 4320494   8c5b64b91c              0.003
# 22666622  e08042d798              0.003
# 4073904   846602988c              0.003
# 12297125  8f8ecbbc13              0.003
# ...

# %%
total_operation_time = total_load_time+merge_time
print("\n\n------------total all operation time",total_operation_time,"seconds-------------------")
# Out:
# ------------total all operation time 486.2582914829254 seconds-------------------
